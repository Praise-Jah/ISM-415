# %%
import pandas as pd

# %%
#To read a data set

data =pd.read_csv('NYC_Property_Data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  BOROUGH   NEIGHBORHOOD  \
# 0           0             4        1  ALPHABET CITY
# 1           1             5        1  ALPHABET CITY
# 2           2             6        1  ALPHABET CITY
# 3           3             7        1  ALPHABET CITY
# 4           4             8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                        C2            153 AVENUE B  ...
# 1   26                        C7   234 EAST 4TH   STREET  ...
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                            0
# Unnamed: 0.1                          0
# BOROUGH                               0
# NEIGHBORHOOD                          0
# BUILDING CLASS CATEGORY               0
# TAX CLASS AT PRESENT                738
# BLOCK                                 0
# LOT                                   0
# BUILDING CLASS AT PRESENT           738
# ADDRESS                               0
# ZIP CODE                              0
# RESIDENTIAL UNITS                     0
# COMMERCIAL UNITS                      0
# TOTAL UNITS                           0
# LAND SQUARE FEET                  26252
# GROSS SQUARE FEET                 27612
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                        14561
# SALE DATE                             0
# dtype: int64

# %%
data
# Out:
#        Unnamed: 0  Unnamed: 0.1  BOROUGH   NEIGHBORHOOD  \
# 0               0             4        1  ALPHABET CITY
# 1               1             5        1  ALPHABET CITY
# 2               2             6        1  ALPHABET CITY
# 3               3             7        1  ALPHABET CITY
# 4               4             8        1  ALPHABET CITY
# ...           ...           ...      ...            ...
# 84543       84543          8409        5        WOODROW
# 84544       84544          8410        5        WOODROW
# 84545       84545          8411        5        WOODROW
# 84546       84546          8412        5        WOODROW
# 84547       84547          8413        5        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# ...

# %%
#To drop missing values

data.dropna(how ='any', inplace = True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                        0
# Unnamed: 0.1                      0
# BOROUGH                           0
# NEIGHBORHOOD                      0
# BUILDING CLASS CATEGORY           0
# TAX CLASS AT PRESENT              0
# BLOCK                             0
# LOT                               0
# BUILDING CLASS AT PRESENT         0
# ADDRESS                           0
# ZIP CODE                          0
# RESIDENTIAL UNITS                 0
# COMMERCIAL UNITS                  0
# TOTAL UNITS                       0
# LAND SQUARE FEET                  0
# GROSS SQUARE FEET                 0
# YEAR BUILT                        0
# TAX CLASS AT TIME OF SALE         0
# BUILDING CLASS AT TIME OF SALE    0
# SALE PRICE                        0
# SALE DATE                         0
# dtype: int64

# %%
data = data.dropna(axis=0, subset=['SALE PRICE', 'LAND SQUARE FEET', 'GROSS SQUARE FEET'])

# %%
data = pd.get_dummies(data=data, columns=['BOROUGH','TAX CLASS AT TIME OF SALE','BUILDING CLASS AT TIME OF SALE'])

# %%
A = data.drop('SALE PRICE', axis=1)

# %%
B = data['SALE PRICE']

# %%
B
# Out:
# 0         6625000.0
# 3         3936272.0
# 4         8000000.0
# 6         3192840.0
# 9        16232000.0
#             ...
# 84543      450000.0
# 84544      550000.0
# 84545      460000.0
# 84546    11693337.0
# 84547       69300.0
# Name: SALE PRICE, Length: 47892, dtype: float64

# %%
#To import the train test split

from sklearn.model_selection import train_test_split

# %%
#Assign variables to split

A_train, A_test, B_train, B_test = train_test_split(A,B, test_size = 0.2, random_state = 101)

# %%
A_train
# Out:
#        BLOCK   LOT  ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 22087   3938  3842     10462                  1                 0
# 54591   1698    34     11369                  1                 1
# 25976   6110     1     11209                  2                 0
# 81587   1008     7     10302                  1                 0
# 47079    846    24     11220                  2                 0
# ...      ...   ...       ...                ...               ...
# 22995   5845  1825     10471                  0                 0
# 25306   3387    24     10470                  2                 0
# 35116   3932     5     11207                  6                 0
# 35316     45  1067     11201                  1                 0
# 81389   4026    13     10306                  1                 0
#
#        TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 22087            1               0.0                0.0           0
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
model = regressor.fit(A_train, B_train)

# %%
B_pred = model.predict(A_test)

# %%
pd.DataFrame({'Actual':B_test, 'Predicted': B_pred, 'Error': B_test-B_pred})
# Out:
#           Actual     Predicted         Error
# 31827        0.0  5.962037e+05 -5.962037e+05
# 26956  2520000.0  1.032359e+06  1.487641e+06
# 72229   290000.0  4.004923e+05 -1.104923e+05
# 32532   540000.0  2.816297e+05  2.583703e+05
# 28382        0.0  1.201926e+05 -1.201926e+05
# ...          ...           ...           ...
# 23525   500000.0 -7.795131e+04  5.779513e+05
# 42308  1350000.0  2.235851e+05  1.126415e+06
# 20729        0.0 -6.073841e+05  6.073841e+05
# 18386    95000.0  4.740867e+04  4.759133e+04
# 53250       10.0  1.133264e+06 -1.133254e+06
#
# [9579 rows x 3 columns]
