# %% [markdown]
# ## First of all, we have to import all the libraries we will use to start our data analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline
print('All libraries imported')
# Out:
# All libraries imported

# %% [markdown]
# ## Here, we have to set up our parameters like color, size for aesthetics

# %%
#Set up the parameters
# %matplotlib inline 

plt.rcParams['figure.figsize'] = [20.0, 7.0]
plt.rcParams.update({'font.size': 22,})

sns.set_palette('dark') 
sns.set_style('white') 
sns.set_context('talk', font_scale=0.8)

# %% [markdown]
# ## We import our data here and further view the first five rows of the data

# %%
praisedata = pd.read_csv('train_data.csv') 
praisedata.head()

praisedata1 = pd.read_csv('test_data.csv') 
praisedata1.head()
# Out:
#    CustomerId    Surname  CreditScore Geography Gender  Age  Tenure  \
# 0    15642544  Henderson          723    France   Male   34       5
# 1    15779492  Trevisano          796     Spain   Male   56       6
# 2    15815271    Ritchie          755   Germany   Male   43       6
# 3    15582591  Chiabuotu          615     Spain   Male   59       4
# 4    15595937      Bruno          430   Germany   Male   36       1
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0       0.00              2          0               1         12092.03
# 1   94231.13              1          0               0        121164.60
# 2  165048.50              3          1               0         16929.41
# 3  155766.05              1          1               1        110275.17
# 4  138992.48              2          0               0        122373.42

# %% [markdown]
# ## To see the different columns

# %%
#Dataset columns
praisedata.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# ## To get the data size and to see the rows and columns in our dataset

# %%
#To get the data size

praisedata.shape
# Out:
# (7000, 13)

# %%
#Dataset header

praisedata.head()
# Out:
#    CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15804610     Valdez          601    France  Female   41       1
# 1    15574523      Cheng          576    France    Male   39       1
# 2    15587443  Akudinobi          728    France  Female   69       1
# 3    15768682      Amies          640     Spain    Male   39       3
# 4    15569682     Leckie          768   Germany    Male   37       9
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              2          0               1        160607.06
# 1       0.00              2          1               1         68814.23
# 2       0.00              2          1               1        131804.86
# 3       0.00              1          1               1        105997.25
# 4  108308.11              1          1               0         41788.25
#
#    Exited
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1

# %% [markdown]
# ## To check for missing values

# %%
#Sum the missing values in the data

praisedata.isnull().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ## To view the diifferent gender we have

# %%
praisedata.Gender.value_counts()
# Out:
# Male      3843
# Female    3157
# Name: Gender, dtype: int64

# %% [markdown]
# ## To view different geography we have

# %%
praisedata.Geography.value_counts()
# Out:
# France     3518
# Germany    1755
# Spain      1727
# Name: Geography, dtype: int64

# %% [markdown]
# ## To get the summary statistics of the data

# %%
praisedata.describe()
# Out:
#          CustomerId  CreditScore          Age       Tenure        Balance  \
# count  7.000000e+03  7000.000000  7000.000000  7000.000000    7000.000000
# mean   1.569078e+07   649.424000    38.932857     5.008143   77006.866360
# std    7.191100e+04    97.478815    10.467815     2.891734   62392.609703
# min    1.556570e+07   350.000000    18.000000     0.000000       0.000000
# 25%    1.562847e+07   582.000000    32.000000     3.000000       0.000000
# 50%    1.569053e+07   651.000000    37.000000     5.000000   97529.180000
# 75%    1.575333e+07   716.000000    44.000000     7.000000  127942.495000
# max    1.581569e+07   850.000000    92.000000    10.000000  250898.090000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count    7000.000000  7000.000000     7000.000000      7000.000000
# mean        1.525857     0.709286        0.514429     99783.685516
# std         0.582318     0.454124        0.499827     57358.455381
# min         1.000000     0.000000        0.000000        90.070000
# 25%         1.000000     0.000000        0.000000     50957.302500
# 50%         1.000000     1.000000        1.000000     99594.475000
# 75%         2.000000     1.000000        1.000000    149462.720000
# max         4.000000     1.000000        1.000000    199953.330000
#
#             Exited
# count  7000.000000
# mean      0.201429
# std       0.401096
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
praisedata.hist(figsize=(40,40))
plt.show()

# %%
sns.countplot('Gender',data = praisedata)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot('Geography',data = praisedata)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## To encode the numeric variables

# %%
#Encoding the categorical variables
from sklearn import preprocessing

#creating label encoader
le = preprocessing.LabelEncoder()

# %%
praisedata['Gender']=le.fit_transform(praisedata['Gender'])

praisedata['Geography']=le.fit_transform(praisedata['Geography'])

# %%
praisedata1['Gender']=le.fit_transform(praisedata1['Gender'])

praisedata1['Geography']=le.fit_transform(praisedata1['Geography'])

# %%
praisedata.head()
# Out:
#    CustomerId    Surname  CreditScore  Geography  Gender  Age  Tenure  \
# 0    15804610     Valdez          601          0       0   41       1
# 1    15574523      Cheng          576          0       1   39       1
# 2    15587443  Akudinobi          728          0       0   69       1
# 3    15768682      Amies          640          2       1   39       3
# 4    15569682     Leckie          768          1       1   37       9
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              2          0               1        160607.06
# 1       0.00              2          1               1         68814.23
# 2       0.00              2          1               1        131804.86
# 3       0.00              1          1               1        105997.25
# 4  108308.11              1          1               0         41788.25
#
#    Exited
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1

# %% [markdown]
# ## Drop surname

# %%
#Since surname is not useful in the data generation, I am dropping it

praisedata.drop('Surname', axis=1, inplace=True)

# %%
praisedata.head()
# Out:
#    CustomerId  CreditScore  Geography  Gender  Age  Tenure    Balance  \
# 0    15804610          601          0       0   41       1       0.00
# 1    15574523          576          0       1   39       1       0.00
# 2    15587443          728          0       0   69       1       0.00
# 3    15768682          640          2       1   39       3       0.00
# 4    15569682          768          1       1   37       9  108308.11
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              2          0               1        160607.06       0
# 1              2          1               1         68814.23       0
# 2              2          1               1        131804.86       0
# 3              1          1               1        105997.25       0
# 4              1          1               0         41788.25       1

# %% [markdown]
# ## Correlations

# %%
praisedata.corr()
# Out:
#                  CustomerId  CreditScore  Geography    Gender       Age  \
# CustomerId         1.000000     0.008499   0.004044 -0.007481  0.009929
# CreditScore        0.008499     1.000000  -0.004482 -0.006991 -0.002511
# Geography          0.004044    -0.004482   1.000000 -0.000257  0.009800
# Gender            -0.007481    -0.006991  -0.000257  1.000000 -0.024932
# Age                0.009929    -0.002511   0.009800 -0.024932  1.000000
# Tenure            -0.018993    -0.006013   0.002723  0.011091  0.001982
# Balance           -0.021439     0.002181   0.071012  0.007610  0.019424
# NumOfProducts      0.011442     0.008048   0.002317 -0.012755 -0.030046
# HasCrCard         -0.019029    -0.008505  -0.008244  0.021000 -0.014927
# IsActiveMember    -0.011828     0.026724   0.001846  0.025304  0.085195
# EstimatedSalary    0.032816    -0.007756  -0.002684 -0.003190  0.009270
# Exited            -0.007060    -0.032201   0.032632 -0.101712  0.288732
#
#                    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# CustomerId      -0.018993 -0.021439       0.011442  -0.019029       -0.011828
# CreditScore     -0.006013  0.002181       0.008048  -0.008505        0.026724
# Geography        0.002723  0.071012       0.002317  -0.008244        0.001846
# Gender           0.011091  0.007610      -0.012755   0.021000        0.025304
# Age              0.001982  0.019424      -0.030046  -0.014927        0.085195
# Tenure           1.000000  0.001221      -0.003052   0.025304       -0.025239
# Balance          0.001221  1.000000      -0.303379  -0.009317       -0.010813
# NumOfProducts   -0.003052 -0.303379       1.000000   0.009249        0.008045
# HasCrCard        0.025304 -0.009317       0.009249   1.000000       -0.020230
# IsActiveMember  -0.025239 -0.010813       0.008045  -0.020230        1.000000
# EstimatedSalary  0.007210  0.018277       0.015463  -0.010966       -0.018574
# Exited          -0.009668  0.111493      -0.040043  -0.008701       -0.167725
#
#                  EstimatedSalary    Exited
# CustomerId              0.032816 -0.007060
# CreditScore            -0.007756 -0.032201
# Geography              -0.002684  0.032632
# Gender                 -0.003190 -0.101712
# Age                     0.009270  0.288732
# Tenure                  0.007210 -0.009668
# Balance                 0.018277  0.111493
# NumOfProducts           0.015463 -0.040043
# HasCrCard              -0.010966 -0.008701
# IsActiveMember         -0.018574 -0.167725
# EstimatedSalary         1.000000  0.016426
# Exited                  0.016426  1.000000

# %%
sns.heatmap(praisedata.corr(), annot=True) 
plt.show()

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(14,14))
plt.title('Dataset Variables', y=1.05, size=15) 
sns.heatmap(praisedata.corr(),linewidths=0.2,vmax=1.1,
            square=True, cmap=colormap, linecolor='black', annot=True)
plt.show()

# %% [markdown]
# ## To calculate the correlations

# %%
# Calculate correlations
corr = praisedata.corr()
mask = np.zeros_like(corr) 
mask[np.triu_indices_from(mask)] = True 
# Heatmap
plt.figure(figsize=(15, 10)) 
sns.heatmap(corr,
            vmax=.5, 
            mask=mask,
            annot=True, fmt='.2f', 
            linewidths=.2, cmap="YlGnBu")
plt.show()

# %% [markdown]
# ## Finding correlations with the target and sort

# %%
correlations = praisedata.corr()['Exited'].sort_values() 
print('Most Positive Correlations: \n', correlations.tail(5)) 
print('\nMost Negative Correlations: \n', correlations.head(5))
# Out:
# Most Positive Correlations:
#  EstimatedSalary    0.016426
# Geography          0.032632
# Balance            0.111493
# Age                0.288732
# Exited             1.000000
# Name: Exited, dtype: float64
#
# Most Negative Correlations:
#  IsActiveMember   -0.167725
# Gender           -0.101712
# NumOfProducts    -0.040043
# CreditScore      -0.032201
# Tenure           -0.009668
# Name: Exited, dtype: float64

# %%
a_train = praisedata[['CreditScore','Age','Balance','NumOfProducts','IsActiveMember','EstimatedSalary','Geography']].values
b_train = praisedata['Exited'].values

# %%
a_test = praisedata1[['CreditScore','Age','Balance','NumOfProducts','IsActiveMember','EstimatedSalary','Geography']]

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression()
classifier.fit(a_train,b_train)
b_pred = classifier.predict(a_test)

# %%
ditto = {'CustomerId' : praisedata1['CustomerId'],'Exited':b_pred}

# %%
answer = pd.DataFrame(ditto)
answer.head()
# Out:
#    CustomerId  Exited
# 0    15642544       0
# 1    15779492       0
# 2    15815271       0
# 3    15582591       0
# 4    15595937       0

# %%
answer.to_csv('answer.csv', index = False)

# %% [markdown]
# ## Decision Tree Classifier
#
# ### Decision trees use multiple algorithms to decide to split a node into two or more sub-nodes.

# %%
fea = praisedata[['CreditScore','Age','Balance','NumOfProducts','IsActiveMember','EstimatedSalary','Geography']]
tar = praisedata['Exited']

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(fea,tar)
print(model.feature_importances_)
feat_importance = pd.Series(model.feature_importances_,index=fea.columns) 
feat_importance.nlargest(15).plot(kind = 'barh')
plt.show()
# Out:
# [0.17417894 0.2714804  0.15376941 0.14871257 0.04003211 0.17267042
#  0.03915615]

# %%
from sklearn.model_selection import train_test_split

# %%
fea_train,fea_test,tar_train,tar_test = train_test_split(fea,tar, test_size = 0.2, random_state = 0)

# %%
fea_train
# Out:
#       CreditScore  Age    Balance  NumOfProducts  IsActiveMember  \
# 6137          850   24       0.00              2               1
# 4778          684   40  137326.65              1               0
# 3149          648   41  123049.21              1               1
# 4638          733   39   91538.51              1               1
# 4110          610   27   87262.40              2               0
# ...           ...  ...        ...            ...             ...
# 4931          724   31  160997.54              2               1
# 3264          515   60  113715.36              1               0
# 1653          673   30   64097.75              1               1
# 2607          735   29       0.00              2               1
# 2732          503   37       0.00              2               1
#
#       EstimatedSalary  Geography
# 6137         13159.90          0
# 4778        186976.60          1
# 3149          5066.76          1
# 4638         93783.00          1
# 4110        182720.07          0
# ...               ...        ...
# 4931         64831.36          1
# 3264         18424.24          1
# 1653         77783.35          0
# 2607         95025.27          2
# 2732         97893.32          0
#
# [5600 rows x 7 columns]

# %% [markdown]
# ## Importing the Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clasifier1 = DecisionTreeClassifier()
model1 = clasifier1.fit(fea_train, tar_train)

# %%
#Prediction

tar_pred = model1.predict(a_test)

# %%
ditto2 = {'CustomerId' : praisedata1['CustomerId'],'Exited':tar_pred}

# %%
answer2 = pd.DataFrame(ditto2)
answer2.head()
# Out:
#    CustomerId  Exited
# 0    15642544       0
# 1    15779492       1
# 2    15815271       1
# 3    15582591       0
# 4    15595937       0

# %%
answer2.to_csv('answer2.csv', index = False)

# %% [markdown]
# # Random Forest Classifier
#
# ### This consists of a large number of individual decision trees that operate as an ensemble.

# %% [markdown]
# ## Importing the random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier 
clasifier2 = RandomForestClassifier(n_estimators=200, ) 
model2 = clasifier2.fit(fea_train, tar_train)

# %%
#Prediction

tar_pred = model2.predict(a_test)

# %%
ditto3 = {'CustomerId' : praisedata1['CustomerId'],'Exited':tar_pred}

# %%
answer3 = pd.DataFrame(ditto3)
answer3.head()
# Out:
#    CustomerId  Exited
# 0    15642544       0
# 1    15779492       1
# 2    15815271       1
# 3    15582591       0
# 4    15595937       0

# %%
answer3.to_csv('answer3.csv', index = False)

# %% [markdown]
# # Gradient Boosting Classifier
#
# ### Gradient boosting classifiers are a group of machine learning algorithms that combine many weak learning models together to create a strong predictive model.

# %% [markdown]
# ## Importing the Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
clasifier3 = GradientBoostingClassifier()
model3 = clasifier3.fit(fea_train, tar_train)

# %%
#Prediction

tar_pred = model3.predict(a_test)

# %%
ditto4 = {'CustomerId' : praisedata1['CustomerId'],'Exited':tar_pred}

# %%
answer4 = pd.DataFrame(ditto4)
answer4.head()
# Out:
#    CustomerId  Exited
# 0    15642544       0
# 1    15779492       1
# 2    15815271       1
# 3    15582591       0
# 4    15595937       0

# %%
answer4.to_csv('answer4.csv', index = False)

# %% [markdown]
# # Support Vector Machine
#
# ### Support Vector Machine is a linear model for classification and regression problems.

# %% [markdown]
# ## Importing the Support Vector Machine

# %%
from sklearn.svm import SVC
clasifier4 = SVC(kernel='poly', random_state=0) 
model4 = clasifier4.fit(fea_train, tar_train)

# %%
#Prediction

tar_pred = model4.predict(a_test)

# %%
ditto5 = {'CustomerId' : praisedata1['CustomerId'],'Exited':tar_pred}

# %%
answer5 = pd.DataFrame(ditto5)
answer5.head()
# Out:
#    CustomerId  Exited
# 0    15642544       0
# 1    15779492       0
# 2    15815271       0
# 3    15582591       0
# 4    15595937       0

# %%
answer5.to_csv('answer5.csv', index = False)

# %% [markdown]
# # LGB
#
# ### LightGBM is based on decision tree algorithms and used for ranking, classification and other machine learning tasks.

# %%
import lightgbm as lgb
classifier5 = lgb.LGBMClassifier()
model5 = classifier5.fit(fea_train, tar_train)

# %%
#Prediction

tar_pred = model5.predict(a_test)

# %%
ditto6 = {'CustomerId' : praisedata1['CustomerId'],'Exited':tar_pred}

# %%
answer6 = pd.DataFrame(ditto6)
answer6.head()
# Out:
#    CustomerId  Exited
# 0    15642544       0
# 1    15779492       1
# 2    15815271       1
# 3    15582591       0
# 4    15595937       0

# %%
answer6.to_csv('answer6.csv', index = False)
